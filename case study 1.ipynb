# %% [markdown]
# # 1. Read the dataset to the python environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/sreel/Downloads/cars_data.csv')
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
print(data.isnull().sum())
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3. Plot a bar graph of male vs female buyers participated in the sales.

# %%
gender = data['Buyer Gender'].value_counts()
gender.plot(kind='bar',figsize=(10,8))
plt.title('male vs female buyers participated in the sales.')
# Out:
# Text(0.5, 1.0, 'male vs female buyers participated in the sales.')

# %% [markdown]
# # 4. Find the top 5 cars based on their sales price.

# %%
data.nlargest(5,columns=['Sale Price'],keep='first')
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  \
# 5984               core    Russia    Krasnoyarka        59.418208
# 1270           function    Latvia        Līgatne        57.236340
# 3460           software  Malaysia      Pasir Mas         6.109065
# 9032  internet solution    Russia  Krutaya Gorka        55.369917
# 302         user-facing    Canada       Langford        48.447463
#
#       Dealer Longitude   Color  New Car Purchase Date  Sale Price  Discount  \
# ...

# %%
a=data[['Sale Price','Make','Model']]
a.nlargest(5,columns=['Sale Price'],keep='first')
# Out:
#       Sale Price        Make      Model
# 5984    99997.65  Volkswagen  Jetta III
# 1270    99991.91        Audi         A6
# 3460    99983.38       Lexus         LX
# 9032    99978.17       Mazda       MX-6
# 302     99973.44       Lexus         ES

# %% [markdown]
# # 5. Find the least 5 cars based on their Resell price.

# %%
b=data[['Resell Price','Make','Model']]
b.nsmallest(5,columns=['Resell Price'],keep='first')
# Out:
#       Resell Price        Make        Model
# 2446       2000.84   Chevrolet         1500
# 4933       2005.44         GMC  Savana 1500
# 566        2014.09      Jaguar           XF
# 2538       2017.24  Mitsubishi       3000GT
# 5869       2017.83    Infiniti          G37
